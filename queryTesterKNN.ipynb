# %%
import joblib
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Load the trained kNN model
knn_model_scaled = joblib.load("/content/drive/MyDrive/Colab Notebooks/KNN_model/scaled_knn_model.pkl")

# Read data from the text file
file_path = "/content/drive/MyDrive/Colab Notebooks/hsv_values.txt"

# Load the data using pandas
data = pd.read_csv(file_path)

# Extract the 'Hue (degrees)' column for prediction
query_data = data[['Hue (degrees)']].astype(np.float32)

# Make predictions using the trained kNN model
knn_predictions = knn_model_scaled.predict(query_data)

# Print raw kNN predictions
print("Raw kNN Predictions:", knn_predictions)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Raw kNN Predictions: ['Red']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
